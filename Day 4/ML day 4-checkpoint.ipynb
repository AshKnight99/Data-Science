# %%
import pandas as pd
import io
import csv

# %%
df=pd.read_csv("C:\\Users\\Rachana\\Downloads\\patients_data.csv")

# %%
df
# Out:
#       patient_number state_patient_number date_announced age_bracket gender  \
# 0                  1             KL-TS-P1     30/01/2020          20      F
# 1                  2             KL-AL-P1     02/02/2020         NaN    NaN
# 2                  3             KL-KS-P1     03/02/2020         NaN    NaN
# 3                  4                DL-P1     02/03/2020          45      M
# 4                  5                TS-P1     02/03/2020          24      M
# ...              ...                  ...            ...         ...    ...
# 6820            6821                  NaN     10/04/2020         NaN    NaN
# 6821            6822                  NaN     10/04/2020         NaN    NaN
# 6822            6823                  NaN     10/04/2020         NaN    NaN
# 6823            6824                  NaN     10/04/2020         NaN    NaN
# 6824            6825                  NaN     10/04/2020         NaN    NaN
#
# ...

# %%
df.columns
# Out:
# Index(['patient_number', 'state_patient_number', 'date_announced',
#        'age_bracket', 'gender', 'detected_city', 'detected_district',
#        'detected_state', 'state_code', 'current_status', 'notes',
#        'suspected_contacted_patient', 'nationality', 'type_of_transmission',
#        'status_change_date', 'source_1', 'source_2', 'source_3',
#        'backup_notes'],
#       dtype='object')

# %%
df.dtypes
# Out:
# patient_number                  int64
# state_patient_number           object
# date_announced                 object
# age_bracket                    object
# gender                         object
# detected_city                  object
# detected_district              object
# detected_state                 object
# state_code                     object
# current_status                 object
# notes                          object
# suspected_contacted_patient    object
# nationality                    object
# type_of_transmission           object
# status_change_date             object
# source_1                       object
# source_2                       object
# source_3                       object
# backup_notes                   object
# dtype: object

# %%
df.describe()
# Out:
#        patient_number
# count     6825.000000
# mean      3413.000000
# std       1970.352126
# min          1.000000
# 25%       1707.000000
# 50%       3413.000000
# 75%       5119.000000
# max       6825.000000

# %%
s=pd.Series([20,30,40])
s.describe()
# Out:
# count     3.0
# mean     30.0
# std      10.0
# min      20.0
# 25%      25.0
# 50%      30.0
# 75%      35.0
# max      40.0
# dtype: float64

# %%
pd.Series([20,30,40])
# Out:
# 0    20
# 1    30
# 2    40
# dtype: int64

# %%
df.age_bracket
#df["age_bracket"]
# Out:
# 0        20
# 1       NaN
# 2       NaN
# 3        45
# 4        24
#        ...
# 6820    NaN
# 6821    NaN
# 6822    NaN
# 6823    NaN
# 6824    NaN
# Name: age_bracket, Length: 6825, dtype: object

# %%
df['age_bracket'].describe(include='all')
# Out:
# count     1074
# unique      84
# top         35
# freq        38
# Name: age_bracket, dtype: object

# %%
df.describe(include='all')
# Out:
#         patient_number state_patient_number date_announced age_bracket gender  \
# count      6825.000000                 1308           6825        1074   1672
# unique             NaN                 1303             43          84      2
# top                NaN            UP-GBN-15     09/04/2020          35      M
# freq               NaN                    2            813          38   1219
# mean       3413.000000                  NaN            NaN         NaN    NaN
# std        1970.352126                  NaN            NaN         NaN    NaN
# min           1.000000                  NaN            NaN         NaN    NaN
# 25%        1707.000000                  NaN            NaN         NaN    NaN
# 50%        3413.000000                  NaN            NaN         NaN    NaN
# 75%        5119.000000                  NaN            NaN         NaN    NaN
# max        6825.000000                  NaN            NaN         NaN    NaN
#
# ...

# %%
df['detected_state'].value_counts()
# Out:
# Maharashtra                    1364
# Tamil Nadu                      834
# Delhi                           720
# Rajasthan                       489
# Telangana                       471
# Madhya Pradesh                  411
# Uttar Pradesh                   410
# Andhra Pradesh                  365
# Kerala                          357
# Gujarat                         308
# Karnataka                       197
# Jammu and Kashmir               184
# Haryana                         175
# Punjab                          130
# West Bengal                     116
# Bihar                            60
# Odisha                           48
# Uttarakhand                      35
# Assam                            29
# Himachal Pradesh                 28
# Chandigarh                       18
# Chhattisgarh                     18
# Ladakh                           15
# Jharkhand                        14
# Andaman and Nicobar Islands      11
# Goa                               7
# ...

# %%
df.head(n=10)
# Out:
#    patient_number state_patient_number date_announced age_bracket gender  \
# 0               1             KL-TS-P1     30/01/2020          20      F
# 1               2             KL-AL-P1     02/02/2020         NaN    NaN
# 2               3             KL-KS-P1     03/02/2020         NaN    NaN
# 3               4                DL-P1     02/03/2020          45      M
# 4               5                TS-P1     02/03/2020          24      M
# 5               6                  NaN     03/03/2020          69      M
# 6               7                  NaN     04/03/2020          55    NaN
# 7               8                  NaN     04/03/2020          55    NaN
# 8               9                  NaN     04/03/2020          55    NaN
# 9              10                  NaN     04/03/2020          55    NaN
#
#               detected_city detected_district detected_state state_code  \
# 0                  Thrissur          Thrissur         Kerala         KL
# ...

# %%
#command data manapulations 
# selecting / indexing
# sorting 
# mutating / adding column conditionally 
# grouping / sumarirzine 
df.iloc[0:5,0:2]  #[row,col]
# Out:
#    patient_number state_patient_number
# 0               1             KL-TS-P1
# 1               2             KL-AL-P1
# 2               3             KL-KS-P1
# 3               4                DL-P1
# 4               5                TS-P1

# %%
#Or
df.iloc[0:5,[0,3,5]]
# Out:
#    patient_number age_bracket             detected_city
# 0               1          20                  Thrissur
# 1               2         NaN                 Alappuzha
# 2               3         NaN                 Kasaragod
# 3               4          45  East Delhi (Mayur Vihar)
# 4               5          24                 Hyderabad

# %%
df['age_bracket']=pd.to_numeric(df['age_bracket'],errors='coerce')
df2=df.loc[df["age_bracket"]>40,["state_code","age_bracket"]].head()
df2
# Out:
#   state_code  age_bracket
# 3         DL         45.0
# 5         RJ         69.0
# 6         HR         55.0
# 7         HR         55.0
# 8         HR         55.0

# %%
df.loc[df['detected_city'].isin(['Gurugram'])]
# Out:
#      patient_number state_patient_number date_announced  age_bracket gender  \
# 6                 7                  NaN     04/03/2020         55.0    NaN
# 7                 8                  NaN     04/03/2020         55.0    NaN
# 8                 9                  NaN     04/03/2020         55.0    NaN
# 9                10                  NaN     04/03/2020         55.0    NaN
# 10               11                  NaN     04/03/2020         55.0    NaN
# 11               12                  NaN     04/03/2020         55.0    NaN
# 12               13                  NaN     04/03/2020         55.0    NaN
# 13               14                  NaN     04/03/2020         55.0    NaN
# 14               15                  NaN     04/03/2020         55.0    NaN
# 15               16                  NaN     04/03/2020         55.0    NaN
# 16               17                  NaN     04/03/2020         55.0    NaN
# ...

# %%
df3=df.loc[(df['age_bracket']>40) & (df['detected_city'].isin(['Hyderabad']))]

# %%
df3
# Out:
#      patient_number state_patient_number date_announced  age_bracket gender  \
# 111             112                  NaN     15/03/2020         46.0    NaN
# 140             141                TS-P5     17/03/2020         52.0      M
# 371             372               TS-P27     22/03/2020         50.0      F
#
#     detected_city detected_district detected_state state_code current_status  \
# 111     Hyderabad         Hyderabad      Telangana         TG   Hospitalized
# 140     Hyderabad         Hyderabad      Telangana         TG   Hospitalized
# 371     Hyderabad         Hyderabad      Telangana         TG   Hospitalized
#
#                                                  notes  \
# 111                 Travelled from Netherlands March 9
# 140  Indonesian national; The patient had flown int...
# 371                               Travelled from Dubai
#
#     suspected_contacted_patient nationality type_of_transmission  \
# ...

# %%
#using population.csv
df1=pd.read_csv("C:\\Users\\Rachana\\Downloads\\population_india_census2011.csv")

# %%
df1.columns
# Out:
# Index(['Sno', 'State / Union Territory', 'Population', 'Rural population',
#        'Urban population', 'Area', 'Density', 'Gender Ratio'],
#       dtype='object')

# %%
df1
# Out:
#     Sno                   State / Union Territory  Population  \
# 0     1                             Uttar Pradesh   199812341
# 1     2                               Maharashtra   112374333
# 2     3                                     Bihar   104099452
# 3     4                               West Bengal    91276115
# 4     5                            Madhya Pradesh    72626809
# 5     6                                Tamil Nadu    72147030
# 6     7                                 Rajasthan    68548437
# 7     8                                 Karnataka    61095297
# 8     9                                   Gujarat    60439692
# 9    10                            Andhra Pradesh    49577103
# 10   11                                    Odisha    41974218
# 11   12                                 Telengana    35003674
# 12   13                                    Kerala    33406061
# 13   14                                 Jharkhand    32988134
# ...

# %%
df1.info
# Out:
# <bound method DataFrame.info of     Sno                   State / Union Territory  Population  \
# 0     1                             Uttar Pradesh   199812341
# 1     2                               Maharashtra   112374333
# 2     3                                     Bihar   104099452
# 3     4                               West Bengal    91276115
# 4     5                            Madhya Pradesh    72626809
# 5     6                                Tamil Nadu    72147030
# 6     7                                 Rajasthan    68548437
# 7     8                                 Karnataka    61095297
# 8     9                                   Gujarat    60439692
# 9    10                            Andhra Pradesh    49577103
# 10   11                                    Odisha    41974218
# 11   12                                 Telengana    35003674
# 12   13                                    Kerala    33406061
# 13   14                                 Jharkhand    32988134
# ...

# %%
df2=df.loc[df["age_bracket"]>40,["detected_district","age_bracket"]]
df2.reset_index(drop=True)
# Out:
#     detected_district  age_bracket
# 0          East Delhi         45.0
# 1           Italians*         69.0
# 2           Italians*         55.0
# 3           Italians*         55.0
# 4           Italians*         55.0
# ..                ...          ...
# 488   Chikkaballapura         48.0
# 489         Jalandhar         42.0
# 490         Jalandhar         74.0
# 491         Jalandhar         63.0
# 492             Siwan         60.0
#
# [493 rows x 2 columns]

# %%
df.sort_values(['detected_city'],ascending=False).head(n=10)
# Out:
#       patient_number state_patient_number date_announced  age_bracket gender  \
# 1813            1814              TN-P229     01/04/2020         36.0      M
# 104              105                  NaN     14/03/2020          NaN    NaN
# 103              104                  NaN     14/03/2020          NaN    NaN
# 309              310                  NaN     21/03/2020          NaN    NaN
# 124              125                  NaN     16/03/2020         51.0      F
# 952              953               TN-P42     28/03/2020         25.0      M
# 253              254                  NaN     20/03/2020         32.0      M
# 651              652               TN-P25     25/03/2020         26.0      M
# 396              397                AP-P6     22/03/2020         49.0      F
# 492              493                AP-P7     23/03/2020         25.0      M
#
#       detected_city detected_district  detected_state state_code  \
# ...

# %%
df.sort_values(['detected_city','age_bracket'],ascending=[False,True]).head(n=10)
# Out:
#       patient_number state_patient_number date_announced  age_bracket gender  \
# 1813            1814              TN-P229     01/04/2020         36.0      M
# 124              125                  NaN     16/03/2020         51.0      F
# 103              104                  NaN     14/03/2020          NaN    NaN
# 104              105                  NaN     14/03/2020          NaN    NaN
# 309              310                  NaN     21/03/2020          NaN    NaN
# 952              953               TN-P42     28/03/2020         25.0      M
# 253              254                  NaN     20/03/2020         32.0      M
# 651              652               TN-P25     25/03/2020         26.0      M
# 492              493                AP-P7     23/03/2020         25.0      M
# 396              397                AP-P6     22/03/2020         49.0      F
#
#       detected_city detected_district  detected_state state_code  \
# ...

# %%
df[['patient_number','age_bracket']]
# Out:
#       patient_number  age_bracket
# 0                  1         20.0
# 1                  2          NaN
# 2                  3          NaN
# 3                  4         45.0
# 4                  5         24.0
# ...              ...          ...
# 6820            6821          NaN
# 6821            6822          NaN
# 6822            6823          NaN
# 6823            6824          NaN
# 6824            6825          NaN
#
# [6825 rows x 2 columns]

# %%
#filtering
df['age_bracket']=pd.to_numeric(df['age_bracket'],errors='coerce')
print(df[df['age_bracket'] > 40])
# Out:
#       patient_number state_patient_number date_announced  age_bracket gender  \
# 3                  4                DL-P1     02/03/2020         45.0      M
# 5                  6                  NaN     03/03/2020         69.0      M
# 6                  7                  NaN     04/03/2020         55.0    NaN
# 7                  8                  NaN     04/03/2020         55.0    NaN
# 8                  9                  NaN     04/03/2020         55.0    NaN
# ...              ...                  ...            ...          ...    ...
# 6216            6217              KA-P191     09/04/2020         48.0      F
# 6217            6218                  NaN     09/04/2020         42.0      F
# 6218            6219                  NaN     09/04/2020         74.0      F
# 6219            6220                  NaN     09/04/2020         63.0      M
# 6692            6693                  NaN     09/04/2020         60.0      M
#
# ...

# %%
print(df.loc[df['detected_state'].isin(["Maharashtra"])])
# Out:
#       p_no state_patient_number date_announced  age_bracket gender  \
# 43       5                  NaN     09/03/2020          NaN      M
# 44       5                  NaN     09/03/2020          NaN      F
# 59       5                  NaN     10/03/2020          3.0      F
# 60       5                  NaN     10/03/2020          NaN    NaN
# 61       5                  NaN     10/03/2020          NaN      M
# ...    ...                  ...            ...          ...    ...
# 6706     5                  NaN     09/04/2020          NaN    NaN
# 6707     5                  NaN     09/04/2020          NaN    NaN
# 6708     5                  NaN     09/04/2020          NaN    NaN
# 6709     5                  NaN     09/04/2020          NaN    NaN
# 6710     5                  NaN     09/04/2020          NaN    NaN
#
#      detected_city detected_district detected_state state_code current_status  \
# 43            Pune              Pune    Maharashtra         MH      Recovered
# ...

# %%
import numpy as np
df.loc[1,['state_patient_number']]=np.nan    #makes value null/nan 
print(df.iloc[9:11])
# Out:
#     p_no state_patient_number date_announced  age_bracket gender  \
# 9      5                  NaN     04/03/2020         55.0    NaN
# 10     5                  NaN     04/03/2020         55.0    NaN
#
#    detected_city detected_district detected_state state_code current_status  \
# 9       Gurugram         Italians*        Haryana         HR      Recovered
# 10      Gurugram         Italians*        Haryana         HR      Recovered
#
#                    notes suspected_contacted_patient nationality  \
# 9   Travelled from Italy                          P6       Italy
# 10  Travelled from Italy                          P6       Italy
#
#    type_of_transmission status_change_date  \
# 9              Imported         29/03/2020
# 10             Imported         29/03/2020
#
#                                              source_1  \
# 9   https://indianexpress.com/article/india/corona...
# 10  https://indianexpress.com/article/india/corona...
#
# ...

# %%
df
# Out:
#       p_no state_patient_number date_announced  age_bracket gender  \
# 0        5             KL-TS-P1     30/01/2020         20.0      F
# 1        5                  NaN     02/02/2020          NaN    NaN
# 2        5             KL-KS-P1     03/02/2020          NaN    NaN
# 3        5                DL-P1     02/03/2020         45.0      M
# 4        5                TS-P1     02/03/2020         24.0      M
# ...    ...                  ...            ...          ...    ...
# 6820     5                  NaN     10/04/2020          NaN    NaN
# 6821     5                  NaN     10/04/2020          NaN    NaN
# 6822     5                  NaN     10/04/2020          NaN    NaN
# 6823     5                  NaN     10/04/2020          NaN    NaN
# 6824     5                  NaN     10/04/2020          NaN    NaN
#
#                  detected_city detected_district detected_state state_code  \
# 0                     Thrissur          Thrissur         Kerala         KL
# ...

# %%
#df['patient_number']=np.array([5]*len(df))
#df['patient_number']

# %%
#renaming column
df.rename(columns={'patient_number':'p_no'})
df
# Out:
#       p_no state_patient_number date_announced  age_bracket gender  \
# 0        5             KL-TS-P1     30/01/2020         20.0      F
# 1        5                  NaN     02/02/2020          NaN    NaN
# 2        5             KL-KS-P1     03/02/2020          NaN    NaN
# 3        5                DL-P1     02/03/2020         45.0      M
# 4        5                TS-P1     02/03/2020         24.0      M
# ...    ...                  ...            ...          ...    ...
# 6820     5                  NaN     10/04/2020          NaN    NaN
# 6821     5                  NaN     10/04/2020          NaN    NaN
# 6822     5                  NaN     10/04/2020          NaN    NaN
# 6823     5                  NaN     10/04/2020          NaN    NaN
# 6824     5                  NaN     10/04/2020          NaN    NaN
#
#                  detected_city detected_district detected_state state_code  \
# 0                     Thrissur          Thrissur         Kerala         KL
# ...

# %%
df.rename({'p_no':'patient_number'},inplace=True)
df
# Out:
#       p_no state_patient_number date_announced  age_bracket gender  \
# 0        5             KL-TS-P1     30/01/2020         20.0      F
# 1        5                  NaN     02/02/2020          NaN    NaN
# 2        5             KL-KS-P1     03/02/2020          NaN    NaN
# 3        5                DL-P1     02/03/2020         45.0      M
# 4        5                TS-P1     02/03/2020         24.0      M
# ...    ...                  ...            ...          ...    ...
# 6820     5                  NaN     10/04/2020          NaN    NaN
# 6821     5                  NaN     10/04/2020          NaN    NaN
# 6822     5                  NaN     10/04/2020          NaN    NaN
# 6823     5                  NaN     10/04/2020          NaN    NaN
# 6824     5                  NaN     10/04/2020          NaN    NaN
#
#                  detected_city detected_district detected_state state_code  \
# 0                     Thrissur          Thrissur         Kerala         KL
# ...

# %%
df.rename(columns={'p_no':'patient_number'})
# Out:
#       patient_number state_patient_number date_announced  age_bracket gender  \
# 0                  5             KL-TS-P1     30/01/2020         20.0      F
# 1                  5                  NaN     02/02/2020          NaN    NaN
# 2                  5             KL-KS-P1     03/02/2020          NaN    NaN
# 3                  5                DL-P1     02/03/2020         45.0      M
# 4                  5                TS-P1     02/03/2020         24.0      M
# ...              ...                  ...            ...          ...    ...
# 6820               5                  NaN     10/04/2020          NaN    NaN
# 6821               5                  NaN     10/04/2020          NaN    NaN
# 6822               5                  NaN     10/04/2020          NaN    NaN
# 6823               5                  NaN     10/04/2020          NaN    NaN
# 6824               5                  NaN     10/04/2020          NaN    NaN
#
# ...

# %%
#using iterator
for index,row in df.iterrows():
    print(index,row['age_bracket'],row['detected_state'])
# Out:
# 0 20.0 Kerala
# 1 nan Kerala
# 2 nan Kerala
# 3 45.0 Delhi
# 4 24.0 Telangana
# 5 69.0 Rajasthan
# 6 55.0 Haryana
# 7 55.0 Haryana
# 8 55.0 Haryana
# 9 55.0 Haryana
# 10 55.0 Haryana
# 11 55.0 Haryana
# 12 55.0 Haryana
# 13 55.0 Haryana
# 14 55.0 Haryana
# 15 55.0 Haryana
# 16 55.0 Haryana
# 17 55.0 Haryana
# 18 55.0 Haryana
# 19 55.0 Haryana
# 20 70.0 Rajasthan
# 21 nan Uttar Pradesh
# 22 nan Uttar Pradesh
# 23 45.0 Uttar Pradesh
# 24 nan Uttar Pradesh
# 25 16.0 Uttar Pradesh
# 26 nan Uttar Pradesh
# 27 nan Uttar Pradesh
# 28 27.0 Delhi
# 29 59.0 Uttar Pradesh
# 30 nan Delhi
# 31 65.0 Ladakh
# 32 75.0 Ladakh
# 33 45.0 Tamil Nadu
# 34 24.0 Kerala
# 35 54.0 Kerala
# 36 53.0 Kerala
# 37 65.0 Kerala
# 38 61.0 Kerala
# 39 25.0 Delhi
# 40 63.0 Jammu and Kashmir
# 41 nan Karnataka
# 42 3.0 Kerala
# 43 nan Maharashtra
# 44 nan Maharashtra
# 45 nan Punjab
# 46 48.0 Uttar Pradesh
# 47 nan Uttar Pradesh
# 48 nan Kerala
# 49 nan Kerala
# 50 40.0 Karnataka
# 51 nan Karnataka
# 52 13.0 Karnataka
# ...

# %%
#writing to csv
df.to_csv('Patient.csv')
